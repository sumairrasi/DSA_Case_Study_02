# %% [markdown]
# # 1. Find out how many males and females participated in the test.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv ('StudentsPerformance.csv')

# %%
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# # 2. What do you think about the student's parental level of education?

# %%
data[['parental level of education']].value_counts()
# Out:
# parental level of education
# some college                   226
# associate's degree             222
# high school                    196
# some high school               179
# bachelor's degree              118
# master's degree                 59
# dtype: int64

# %%
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
sns.countplot(data['parental level of education'])
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'some high school'),
#   Text(1, 0, 'high school'),
#   Text(2, 0, 'some college'),
#   Text(3, 0, "associate's degree"),
#   Text(4, 0, "bachelor's degree"),
#   Text(5, 0, "master's degree")])

# %%
#Here we clear that most of them prefer some college

# %% [markdown]
# # 3. Who scores the most on average for math, reading and writing based on

# %% [markdown]
# # 1 .Gender

# %%
data1 = data['math score'].mean()
data2 = data['reading score'].mean()
data3 = data['writing score'].mean()

# %%
datavg = data[data['math score'] > data1 ]
datavg1 = datavg[datavg['reading score'] > data2 ]
datavg2 = datavg1[datavg1['writing score'] > data3 ]

# %%
datavg2
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 297  female        group B           bachelor's degree      standard
# 298  female        group B            some high school      standard
# 299  female        group B                 high school  free/reduced
# 300  female        group B                 high school  free/reduced
# 302  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
datavg2['gender'].value_counts()
# Out:
# female    213
# male      165
# Name: gender, dtype: int64

# %%
#Female scores most of Scores

# %% [markdown]
# # 2.Test preparation course

# %%
datavg2['test preparation course'].value_counts()
# Out:
# none         198
# completed    180
# Name: test preparation course, dtype: int64

# %%
#None who completed the course scored on Average

# %% [markdown]
# # 4. What do you think about the scoring variation for math, reading and writing based on

# %% [markdown]
# # 1.Gender

# %%
fem=data[data['gender']=='female']
mal=data[data['gender']=='male']

# %%
fem.plot(kind='line', y='math score')
plt.title("Female math scores")
fem.plot(kind='line', y='reading score')
plt.title("Female reading scores")
fem.plot(kind='line', y='writing score')
plt.title("Female writing scores")
# Out:
# Text(0.5, 1.0, 'Female writing scores')

# %%
mal.plot(kind='line', y='math score')
plt.title("male math scores")
mal.plot(kind='line', y='reading score')
plt.title("male reading scores")
mal.plot(kind='line', y='writing score')
plt.title("male writing scores")
# Out:
# Text(0.5, 1.0, 'male writing scores')

# %% [markdown]
# # 2.Test preparation course

# %%
tst1=data[data['test preparation course']=='none']
tst2=data[data['test preparation course']=='completed']

# %%
tst1.plot(kind='line', y='math score')
plt.title("none math scores")
tst1.plot(kind='line', y='reading score')
plt.title("none reading scores")
tst1.plot(kind='line', y='writing score')
plt.title("none writing scores")
# Out:
# Text(0.5, 1.0, 'none writing scores')

# %%
tst2.plot(kind='line', y='math score')
plt.title("completed math scores")
tst2.plot(kind='line', y='reading score')
plt.title("completed reading scores")
tst2.plot(kind='line', y='writing score')
plt.title("completed writing scores")
# Out:
# Text(0.5, 1.0, 'completed writing scores')

# %% [markdown]
# # 5. The management needs your help to give bonus points to the top 25% of students based on their maths score, so how will you help the management to achieve this.

# %%
data5 = data.nlargest(250, ['math score'])

# %%
data5
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 515  female        group E                some college      standard
# 516  female        group E           bachelor's degree      standard
# 517  female        group E          associate's degree      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 428  female        group D                some college  free/reduced
# 429  female        group E            some high school      standard
# 849    male        group A           bachelor's degree      standard
# 850    male        group C          associate's degree  free/reduced
# 851    male        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...
